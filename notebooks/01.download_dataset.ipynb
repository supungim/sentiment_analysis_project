# %%
import numpy as  np

# %%
import json
with open('../artifacts/kaggle.json','r') as  file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'supungimhan', 'key': '3c422fd28daa7b790b320f312e7143da'}

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (1.7.4.5)
# Requirement already satisfied: bleach in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (6.30.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (80.3.1)
# Requirement already satisfied: six>=1.10 in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: colorama in c:\users\supun\desktop\sentiment_analysis_project\env\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Replace these with your actual credentials
os.environ['KAGGLE_USERNAME'] = 'supungimhan'
os.environ['KAGGLE_KEY'] = '3c422fd28daa7b790b320f312e7143da'

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
...

# %%
api = KaggleApi()
api.authenticate()

# %% [markdown]
# from kaggle.api.kaggle_api_extended import KaggleApi

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
